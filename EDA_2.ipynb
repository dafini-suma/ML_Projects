# %% [markdown]
# ### Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %%
data =pd.read_csv("D:\\ALL DATA SCIENCE\\Learn Digital\\DataSets\\iris.csv")

# %%
data.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data['Species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
data['Species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: Species, dtype: int64

# %%
labelencoder = LabelEncoder()
data['Species_Labels'] = labelencoder.fit_transform(data1.iloc[:,-1])

# %%
data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      Species_Labels
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...

# %%
data['Species_Labels'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: Species_Labels, dtype: int64

# %% [markdown]
# ### One Hot Encoder

# %% [markdown]
# #### Using Pandas

# %%
import pandas as pd

# %%
data_encoded=pd.get_dummies(data)

# %%
data_encoded
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species_Labels  \
# 0             5.1          3.5           1.4          0.2               0
# 1             4.9          3.0           1.4          0.2               0
# 2             4.7          3.2           1.3          0.2               0
# 3             4.6          3.1           1.5          0.2               0
# 4             5.0          3.6           1.4          0.2               0
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3               2
# 146           6.3          2.5           5.0          1.9               2
# 147           6.5          3.0           5.2          2.0               2
# 148           6.2          3.4           5.4          2.3               2
# 149           5.9          3.0           5.1          1.8               2
#
#      Species_setosa  Species_versicolor  Species_virginica
# ...

# %%
data['Species'].unique()

# %%
Setosa_D=[]
for i in data['Species']:
    if i=='setosa':
        Setosa_D.append(1)
    else:
        Setosa_D.append(0)
        
Setosa_D
data['Setosa_D']=pd.Series(Setosa_D)
data

# %% [markdown]
# ### PPS score

# %%
#install the package
# !pip install ppscore

# %%
import ppscore as pps

# %%
#pps.score(df, "feature_column", "target_column")  syntax
pps.score(data, "Sepal.Length", "Petal.Length")
# Out:
# {'x': 'Sepal.Length',
#  'y': 'Petal.Length',
#  'ppscore': 0.550422595049248,
#  'case': 'regression',
#  'is_valid_score': True,
#  'metric': 'mean absolute error',
#  'baseline_score': 1.4886666666666668,
#  'model_score': 0.6692708968366863,
#  'model': DecisionTreeRegressor()}

# %%
#calculate the whole PPS matrix
pps.matrix(data)
# Out:
#                  x               y   ppscore            case  is_valid_score  \
# 0     Sepal.Length    Sepal.Length  1.000000  predict_itself            True
# 1     Sepal.Length     Sepal.Width  0.000000      regression            True
# 2     Sepal.Length    Petal.Length  0.550423      regression            True
# 3     Sepal.Length     Petal.Width  0.431739      regression            True
# 4     Sepal.Length         Species  0.471649  classification            True
# 5     Sepal.Length  Species_Labels  0.346619      regression            True
# 6      Sepal.Width    Sepal.Length  0.006966      regression            True
# 7      Sepal.Width     Sepal.Width  1.000000  predict_itself            True
# 8      Sepal.Width    Petal.Length  0.172375      regression            True
# 9      Sepal.Width     Petal.Width  0.132858      regression            True
# 10     Sepal.Width         Species  0.156915  classification            True
# ...
