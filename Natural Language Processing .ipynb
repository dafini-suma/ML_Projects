# %%
pip install -U spacy

# %%
# !python -m spacy download en_core_web_md

# %%
pip install nltk

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import string # special operations on strings
import spacy # language models
nlp=spacy.load('en_core_web_md')

# %%
fb=pd.read_csv('D:\\ALL DATA SCIENCE\\Learn Digital\\DataSets\\fb_sentiment.csv')

# %%
fb
# Out:
#      Unnamed: 0                                             FBPost Label
# 0             0  Drug Runners and  a U.S. Senator have somethin...     O
# 1             1  Heres a single, to add, to Kindle. Just read t...     O
# 2             2  If you tire of Non-Fiction.. Check out http://...     O
# 3             3    Ghost of Round Island is supposedly nonfiction.     O
# 4             4  Why is Barnes and Nobles version of the Kindle...     N
# ..          ...                                                ...   ...
# 995         995  I liked it.  Its youth oriented and I think th...     P
# 996         996  I think the point of the commercial is that, e...     P
# 997         997  Kindle 3 is such a great product. I could not ...     P
# 998         998  develop a way to share books!  that is a big d...     N
# 999         999                               I love my kindle! =)     P
#
# [1000 rows x 3 columns]

# %%
fb.drop('Unnamed: 0', axis=1, inplace=True)
fb.head()
# Out:
#                                               FBPost Label
# 0  Drug Runners and  a U.S. Senator have somethin...     O
# 1  Heres a single, to add, to Kindle. Just read t...     O
# 2  If you tire of Non-Fiction.. Check out http://...     O
# 3    Ghost of Round Island is supposedly nonfiction.     O
# 4  Why is Barnes and Nobles version of the Kindle...     N

# %%
fb=[x.strip() for x in fb.FBPost]
fb=[x for x in fb if x]
fb[0:5]
# Out:
# ['Drug Runners and  a U.S. Senator have something to do with the Murder http://www.amazon.com/Circumstantial-Evidence-Getting-Florida-Bozarth-ebook/dp/B004FPZ452/ref=pd_rhf_p_t_1 The State Attorney Knows... NOW So Will You. GET Ypur Copy TODAY',
#  'Heres a single, to add, to Kindle. Just read this 19th century story: "The Ghost of Round Island". Its about a man (French/American Indian) and his dog sled transporting a woman across the ice, from Mackinac Island to Cheboygan - and the ghost that...',
#  'If you tire of Non-Fiction.. Check out http://www.amazon.com/s/ref=nb_sb_noss?url=search-alias%3Daps&field-keywords=danielle+lee+zwissler+&x=0&y=0',
#  'Ghost of Round Island is supposedly nonfiction.',
#  'Why is Barnes and Nobles version of the Kindle so much more expensive than the Kindle?']

# %%
# Joining the list into one string/text
text = ' '.join(fb)
text
# Out:
# 'Drug Runners and  a U.S. Senator have something to do with the Murder http://www.amazon.com/Circumstantial-Evidence-Getting-Florida-Bozarth-ebook/dp/B004FPZ452/ref=pd_rhf_p_t_1 The State Attorney Knows... NOW So Will You. GET Ypur Copy TODAY Heres a single, to add, to Kindle. Just read this 19th century story: "The Ghost of Round Island". Its about a man (French/American Indian) and his dog sled transporting a woman across the ice, from Mackinac Island to Cheboygan - and the ghost that... If you tire of Non-Fiction.. Check out http://www.amazon.com/s/ref=nb_sb_noss?url=search-alias%3Daps&field-keywords=danielle+lee+zwissler+&x=0&y=0 Ghost of Round Island is supposedly nonfiction. Why is Barnes and Nobles version of the Kindle so much more expensive than the Kindle? @Maria:  Do you mean the Nook?  Be careful, books you buy for the Kindle are for that piece of electronics, and vice versa.  I love my Kindle, there are people that swear by the Nook.  They like the color screen.Me?  I wa
# ...

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
words = nltk.word_tokenize(text)
words
# Out:
# ['Drug',
#  'Runners',
#  'and',
#  'a',
#  'U.S',
#  '.',
#  'Senator',
#  'have',
#  'something',
#  'to',
#  'do',
#  'with',
#  'the',
#  'Murder',
#  'http',
#  ':',
#  '//www.amazon.com/Circumstantial-Evidence-Getting-Florida-Bozarth-ebook/dp/B004FPZ452/ref=pd_rhf_p_t_1',
#  'The',
#  'State',
#  'Attorney',
#  'Knows',
#  '...',
#  'NOW',
#  'So',
#  'Will',
#  'You',
#  '.',
#  'GET',
#  'Ypur',
#  'Copy',
#  'TODAY',
#  'Heres',
#  'a',
#  'single',
#  ',',
#  'to',
#  'add',
#  ',',
#  'to',
#  'Kindle',
#  '.',
#  'Just',
#  'read',
#  'this',
#  '19th',
#  'century',
#  'story',
#  ':',
#  '``',
#  'The',
#  'Ghost',
#  'of',
#  'Round',
#  'Island',
#  "''",
#  '.',
#  'Its',
#  'about',
#  'a',
#  'man',
#  '(',
#  'French/American',
#  'Indian',
#  ')',
#  'and',
#  'his',
#  'dog',
#  'sled',
#  'transporting',
#  'a',
#  'woman',
#  'across',
#  'the',
#  'ice',
#  ',',
#  'from',
#  'Mackinac',
#  'Island',
#  'to',
#  'Cheboygan',
#  '-',
#  'and',
#  'the',
# ...

# %%
no_punct= [word for word in words if word.isalnum()]
no_punct
# Out:
# ['Drug',
#  'Runners',
#  'and',
#  'a',
#  'Senator',
#  'have',
#  'something',
#  'to',
#  'do',
#  'with',
#  'the',
#  'Murder',
#  'http',
#  'The',
#  'State',
#  'Attorney',
#  'Knows',
#  'NOW',
#  'So',
#  'Will',
#  'You',
#  'GET',
#  'Ypur',
#  'Copy',
#  'TODAY',
#  'Heres',
#  'a',
#  'single',
#  'to',
#  'add',
#  'to',
#  'Kindle',
#  'Just',
#  'read',
#  'this',
#  '19th',
#  'century',
#  'story',
#  'The',
#  'Ghost',
#  'of',
#  'Round',
#  'Island',
#  'Its',
#  'about',
#  'a',
#  'man',
#  'Indian',
#  'and',
#  'his',
#  'dog',
#  'sled',
#  'transporting',
#  'a',
#  'woman',
#  'across',
#  'the',
#  'ice',
#  'from',
#  'Mackinac',
#  'Island',
#  'to',
#  'Cheboygan',
#  'and',
#  'the',
#  'ghost',
#  'that',
#  'If',
#  'you',
#  'tire',
#  'of',
#  'Check',
#  'out',
#  'http',
#  '3Daps',
#  'Ghost',
#  'of',
#  'Round',
#  'Island',
#  'is',
#  'supposedly',
#  'nonfiction',
#  'Why',
#  'is',
#  'Barnes',
#  'and',
#  'Nobles',
#  'version',
# ...

# %%
lower_words=[x.lower() for x in no_punct]
lower_words
# Out:
# ['drug',
#  'runners',
#  'and',
#  'a',
#  'senator',
#  'have',
#  'something',
#  'to',
#  'do',
#  'with',
#  'the',
#  'murder',
#  'http',
#  'the',
#  'state',
#  'attorney',
#  'knows',
#  'now',
#  'so',
#  'will',
#  'you',
#  'get',
#  'ypur',
#  'copy',
#  'today',
#  'heres',
#  'a',
#  'single',
#  'to',
#  'add',
#  'to',
#  'kindle',
#  'just',
#  'read',
#  'this',
#  '19th',
#  'century',
#  'story',
#  'the',
#  'ghost',
#  'of',
#  'round',
#  'island',
#  'its',
#  'about',
#  'a',
#  'man',
#  'indian',
#  'and',
#  'his',
#  'dog',
#  'sled',
#  'transporting',
#  'a',
#  'woman',
#  'across',
#  'the',
#  'ice',
#  'from',
#  'mackinac',
#  'island',
#  'to',
#  'cheboygan',
#  'and',
#  'the',
#  'ghost',
#  'that',
#  'if',
#  'you',
#  'tire',
#  'of',
#  'check',
#  'out',
#  'http',
#  '3daps',
#  'ghost',
#  'of',
#  'round',
#  'island',
#  'is',
#  'supposedly',
#  'nonfiction',
#  'why',
#  'is',
#  'barnes',
#  'and',
#  'nobles',
#  'version',
# ...

# %%
len(lower_words)
# Out:
# 21880

# %%
#Remove stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
my_stop_words = stopwords.words('english')
my_stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
no_stop_tokens = [word for word in lower_words if not word in my_stop_words]

# %%
no_stop_tokens
# Out:
# ['drug',
#  'runners',
#  'senator',
#  'something',
#  'murder',
#  'http',
#  'state',
#  'attorney',
#  'knows',
#  'get',
#  'ypur',
#  'copy',
#  'today',
#  'heres',
#  'single',
#  'add',
#  'kindle',
#  'read',
#  '19th',
#  'century',
#  'story',
#  'ghost',
#  'round',
#  'island',
#  'man',
#  'indian',
#  'dog',
#  'sled',
#  'transporting',
#  'woman',
#  'across',
#  'ice',
#  'mackinac',
#  'island',
#  'cheboygan',
#  'ghost',
#  'tire',
#  'check',
#  'http',
#  '3daps',
#  'ghost',
#  'round',
#  'island',
#  'supposedly',
#  'nonfiction',
#  'barnes',
#  'nobles',
#  'version',
#  'kindle',
#  'much',
#  'expensive',
#  'kindle',
#  'maria',
#  'mean',
#  'nook',
#  'careful',
#  'books',
#  'buy',
#  'kindle',
#  'piece',
#  'electronics',
#  'vice',
#  'versa',
#  'love',
#  'kindle',
#  'people',
#  'swear',
#  'nook',
#  'like',
#  'color',
#  'want',
#  'ereader',
#  'reader',
#  'dont',
#  'need',
#  'color',
#  'kindle',
#  'battery',
#  'lasts',
# ...

# %%
len(no_stop_tokens)
# Out:
# 11076

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %%
for w in no_stop_tokens:
    print(w, " : ", ps.stem(w))
# Out:
# drug  :  drug
# runners  :  runner
# senator  :  senat
# something  :  someth
# murder  :  murder
# http  :  http
# state  :  state
# attorney  :  attorney
# knows  :  know
# get  :  get
# ypur  :  ypur
# copy  :  copi
# today  :  today
# heres  :  here
# single  :  singl
# add  :  add
# kindle  :  kindl
# read  :  read
# 19th  :  19th
# century  :  centuri
# story  :  stori
# ghost  :  ghost
# round  :  round
# island  :  island
# man  :  man
# indian  :  indian
# dog  :  dog
# sled  :  sled
# transporting  :  transport
# woman  :  woman
# across  :  across
# ice  :  ice
# mackinac  :  mackinac
# island  :  island
# cheboygan  :  cheboygan
# ghost  :  ghost
# tire  :  tire
# check  :  check
# http  :  http
# 3daps  :  3dap
# ghost  :  ghost
# round  :  round
# island  :  island
# supposedly  :  supposedli
# nonfiction  :  nonfict
# barnes  :  barn
# nobles  :  nobl
# version  :  version
# kindle  :  kindl
# much  :  much
# expensive  :  expens
# kindle  :  kindl
# maria  :  maria
# ...

# %%
stemmed_words=[ps.stem(w) for w in no_stop_tokens]
stemmed_words
# Out:
# ['drug',
#  'runner',
#  'senat',
#  'someth',
#  'murder',
#  'http',
#  'state',
#  'attorney',
#  'know',
#  'get',
#  'ypur',
#  'copi',
#  'today',
#  'here',
#  'singl',
#  'add',
#  'kindl',
#  'read',
#  '19th',
#  'centuri',
#  'stori',
#  'ghost',
#  'round',
#  'island',
#  'man',
#  'indian',
#  'dog',
#  'sled',
#  'transport',
#  'woman',
#  'across',
#  'ice',
#  'mackinac',
#  'island',
#  'cheboygan',
#  'ghost',
#  'tire',
#  'check',
#  'http',
#  '3dap',
#  'ghost',
#  'round',
#  'island',
#  'supposedli',
#  'nonfict',
#  'barn',
#  'nobl',
#  'version',
#  'kindl',
#  'much',
#  'expens',
#  'kindl',
#  'maria',
#  'mean',
#  'nook',
#  'care',
#  'book',
#  'buy',
#  'kindl',
#  'piec',
#  'electron',
#  'vice',
#  'versa',
#  'love',
#  'kindl',
#  'peopl',
#  'swear',
#  'nook',
#  'like',
#  'color',
#  'want',
#  'eread',
#  'reader',
#  'dont',
#  'need',
#  'color',
#  'kindl',
#  'batteri',
#  'last',
#  'longer',
#  'unit',
#  'isnt',
#  'heavi',
# ...

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
for w in stemmed_words:
    print(w, " : ", lemmatizer.lemmatize(w))
# Out:
# drug  :  drug
# runner  :  runner
# senat  :  senat
# someth  :  someth
# murder  :  murder
# http  :  http
# state  :  state
# attorney  :  attorney
# know  :  know
# get  :  get
# ypur  :  ypur
# copi  :  copi
# today  :  today
# here  :  here
# singl  :  singl
# add  :  add
# kindl  :  kindl
# read  :  read
# 19th  :  19th
# centuri  :  centuri
# stori  :  stori
# ghost  :  ghost
# round  :  round
# island  :  island
# man  :  man
# indian  :  indian
# dog  :  dog
# sled  :  sled
# transport  :  transport
# woman  :  woman
# across  :  across
# ice  :  ice
# mackinac  :  mackinac
# island  :  island
# cheboygan  :  cheboygan
# ghost  :  ghost
# tire  :  tire
# check  :  check
# http  :  http
# 3dap  :  3dap
# ghost  :  ghost
# round  :  round
# island  :  island
# supposedli  :  supposedli
# nonfict  :  nonfict
# barn  :  barn
# nobl  :  nobl
# version  :  version
# kindl  :  kindl
# much  :  much
# expens  :  expens
# kindl  :  kindl
# maria  :  maria
# mean  :  mean
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
# 2022-03-08 20:50:34.329486: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-03-08 20:50:34.329690: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Joining the list into one string/text
text = ' '.join(no_stop_tokens)
text
# Out:
# 'drug runners senator something murder http state attorney knows get ypur copy today heres single add kindle read 19th century story ghost round island man indian dog sled transporting woman across ice mackinac island cheboygan ghost tire check http 3daps ghost round island supposedly nonfiction barnes nobles version kindle much expensive kindle maria mean nook careful books buy kindle piece electronics vice versa love kindle people swear nook like color want ereader reader dont need color kindle battery lasts longer unit isnt heavy make difference reading hours kindle awesome mines great love mine meh think singles bad idea big name authors already dominate market huge factor letting compete price point indie authors albeit giving less content money daugjhter loves sure got update dont location numbers unless press menu button also dont page numbers something wrong got kindle xmas love never much book reader fun 5th book since christmas dont patience kindle singles im gon na read ne
# ...

# %%
processed=nlp(text)
for token in processed:
    print(token.text, '\t', token.pos_, '\t', token.lemma_)
    #print(token.text, '\t', token.pos_, '\t', token.lemma, '\t', token.lemma_)
# Out:
# drug 	 NOUN 	 drug
# runners 	 NOUN 	 runner
# senator 	 NOUN 	 senator
# something 	 PRON 	 something
# murder 	 NOUN 	 murder
# http 	 PROPN 	 http
# state 	 NOUN 	 state
# attorney 	 NOUN 	 attorney
# knows 	 VERB 	 know
# get 	 VERB 	 get
# ypur 	 PROPN 	 ypur
# copy 	 NOUN 	 copy
# today 	 NOUN 	 today
# heres 	 VERB 	 here
# single 	 ADJ 	 single
# add 	 VERB 	 add
# kindle 	 NOUN 	 kindle
# read 	 VERB 	 read
# 19th 	 ADJ 	 19th
# century 	 NOUN 	 century
# story 	 NOUN 	 story
# ghost 	 NOUN 	 ghost
# round 	 PROPN 	 round
# island 	 NOUN 	 island
# man 	 NOUN 	 man
# indian 	 ADJ 	 indian
# dog 	 NOUN 	 dog
# sled 	 VERB 	 sle
# transporting 	 VERB 	 transport
# woman 	 NOUN 	 woman
# across 	 ADP 	 across
# ice 	 NOUN 	 ice
# mackinac 	 ADJ 	 mackinac
# island 	 NOUN 	 island
# cheboygan 	 PROPN 	 cheboygan
# ghost 	 NOUN 	 ghost
# tire 	 NOUN 	 tire
# check 	 VERB 	 check
# http 	 NOUN 	 http
# 3daps 	 NUM 	 3daps
# ghost 	 NOUN 	 ghost
# round 	 ADJ 	 round
# ...
